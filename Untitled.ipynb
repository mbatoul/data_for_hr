# %%
import pandas as pd

# %%
df_candidates = pd.read_csv("data/candidates012020.csv")

# %%
df_candidates
# Out:
#       id  age  gender  selective_college   gpa  extra_curriculars  \
# 0      7   23       1                  0  3.06                  5
# 1   1266   27       0                  0  2.82                  4
# 2   1548   29       0                  1  3.14                  1
# 3   2386   26       1                  0  3.86                  1
# 4   2509   28       1                  1  3.51                  1
# 5   2898   28       0                  0  3.15                  1
# 6   2962   28       1                  0  3.64                  2
# 7   3388   25       1                  1  3.30                  5
# 8   4869   27       1                  0  2.99                  3
# 9   5288   29       1                  0  3.26                  1
# 10  6353   26       0                  1  3.14                  2
# 11  6848   24       0                  0  2.80                  5
# 12  7021   29       0                  0  3.27                  5
# ...

# %%
df_performances = pd.read_csv("data/hiringperformance012020.csv", index_col="Unnamed: 0")

# %%
df_performances
# Out:
#      outsideexp  tenure  gender  selective_college  modelling_test  \
# 1             1       2       0                  0              86
# 2             1       1       1                  1              78
# 3             3       1       1                  0              74
# 4             4       2       1                  1              78
# 5             2       2       1                  0              77
# ..          ...     ...     ...                ...             ...
# 146           0       2       1                  0              75
# 147           5       1       0                  0              73
# 148           1       2       0                  1              79
# 149           2       4       1                  0              86
# 150           0       2       0                  0              71
#
#      extra_curriculars   gpa  collaborativeness  grit  maturity  ambition  \
# 1                    4  3.17                  2     3         4         2
# ...
